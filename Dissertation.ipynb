# %% [markdown]
# <a href="https://colab.research.google.com/github/19A55A0412/Hybrid-Network-Design-Cisco-Packet-Tracer/blob/main/Dissertation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy pandas matplotlib opencv-python torch torchvision monai SimpleITK
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 29.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 MB 16.6 MB/s eta 0:00:00
# ...

# %%
import os

os.makedirs("/content/images", exist_ok=True)
os.makedirs("/content/masks", exist_ok=True)

print("Folders created!")
# Out:
# Folders created!

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.listdir('/content/')
# Out:
# ['.config',
#  'SSMSpine_Test_Sample.zip',
#  'masks',
#  'drive',
#  'CTSpine1K.zip',
#  'SSMSpine_Train_Sample.zip',
#  'images',
#  'sample_data']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d67ca336-73a2-4544-bbe6-03459f2c9ba3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d67ca336-73a2-4544-bbe6-03459f2c9ba3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !ls /content
# Out:
# CTSpine1K.zip  sample_data  SSMSpine_Test_Sample.zip  SSMSpine_Train_Sample.zip

# %%
# !unzip CTSpine1K.zip -d /content/CTSpine1K
# Out:
# Archive:  CTSpine1K.zip
#    creating: /content/CTSpine1K/CTSpine1K/
#   inflating: /content/CTSpine1K/CTSpine1K/metadata_colonog.xlsx
#   inflating: /content/CTSpine1K/CTSpine1K/metadata_neck.xlsx
#   inflating: /content/CTSpine1K/CTSpine1K/readme.txt
#    creating: /content/CTSpine1K/CTSpine1K/test_private/
#    creating: /content/CTSpine1K/CTSpine1K/test_private/gt/
#   inflating: /content/CTSpine1K/CTSpine1K/test_private/gt/1.3.6.1.4.1.9328.50.4.0505_seg.nii.gz
#   inflating: /content/CTSpine1K/CTSpine1K/test_private/gt/1.3.6.1.4.1.9328.50.4.0506_seg.nii.gz
#   inflating: /content/CTSpine1K/CTSpine1K/test_private/gt/1.3.6.1.4.1.9328.50.4.0507_seg.nii.gz
#   inflating: /content/CTSpine1K/CTSpine1K/test_private/gt/1.3.6.1.4.1.9328.50.4.0508_seg.nii.gz
#   inflating: /content/CTSpine1K/CTSpine1K/test_private/gt/1.3.6.1.4.1.9328.50.4.0509_seg.nii.gz
#   inflating: /content/CTSpine1K/CTSpine1K/test_private/gt/1.3.6.1.4.1.9328.50.4.0510_seg.nii.gz
# ...

# %%
# !unzip SSMSpine_Train_Sample.zip -d /content/SSMSpine_Train_Sample
# Out:
# Archive:  SSMSpine_Train_Sample.zip
#    creating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug0.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug1.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug10.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug100.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug101.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug102.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug103.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug104.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug105.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug106.pt
#   inflating: /content/SSMSpine_Train_Sample/SSMSpine_Train_Sample/p0/aug107.pt
# ...

# %%
# !unzip SSMSpine_Test_Sample.zip -d /content/SSMSpine_Test_Sample
# Out:
# Archive:  SSMSpine_Test_Sample.zip
#    creating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug0.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug1.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug10.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug100.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug101.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug102.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug103.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug104.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug105.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug106.pt
#   inflating: /content/SSMSpine_Test_Sample/SSMSpine_Test_Sample/p80/aug107.pt
# ...
